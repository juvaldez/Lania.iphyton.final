# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
# %matplotlib inline

# %%
archivo = '../files/Datos.xls'
pd.read_excel(archivo).head()
# Out:
#              Estación:  XALAPAob,        VER  Unnamed: 3  Unnamed: 4  \
# 0         Operada por:        SMN      ESIME         NaN         NaN
# 1            Longitud:  96°54'14"  Longitud:    19°30'43    Altitud:
# 2                  NaN        NaN        NaN         NaN         NaN
# 3                FECHA       DIRS       DIRR  RAPVIENTO2  RAPRAFAGA2
# 4  2014-11-05 18:00:00        121        244         2.3         5.6
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN        NaN        NaN        NaN        NaN
# 1       1360        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3       TEMP         HR         PB       PREC     RADSOL
# 4       20.9         57      867.5          0        896

# %%
pd.read_excel(archivo, header=4).head()
# Out:
#                 FECHA  DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# 0 2014-11-05 18:00:00   121   244         2.3         5.6  20.9  57  867.5
# 1 2014-11-05 18:10:00   171   258         2.2         4.8  20.3  56  867.2
# 2 2014-11-05 18:20:00   160   331         1.7         3.7  21.1  56  867.0
# 3 2014-11-05 18:30:00   150   233         2.0         4.4  20.7  56  866.9
# 4 2014-11-05 18:40:00   100   164         2.2         4.0  21.0  56  866.6
#
#    PREC  RADSOL
# 0     0     896
# 1     0     848
# 2     0     861
# 3     0     751
# 4     0     704

# %%
pd.read_excel(archivo, header=4, index_col='FECHA').head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-05 18:00:00   121   244         2.3         5.6  20.9  57  867.5
# 2014-11-05 18:10:00   171   258         2.2         4.8  20.3  56  867.2
# 2014-11-05 18:20:00   160   331         1.7         3.7  21.1  56  867.0
# 2014-11-05 18:30:00   150   233         2.0         4.4  20.7  56  866.9
# 2014-11-05 18:40:00   100   164         2.2         4.0  21.0  56  866.6
#
#                      PREC  RADSOL
# FECHA
# 2014-11-05 18:00:00     0     896
# 2014-11-05 18:10:00     0     848
# 2014-11-05 18:20:00     0     861
# 2014-11-05 18:30:00     0     751
# 2014-11-05 18:40:00     0     704

# %%
xalapaOb =pd.read_excel(archivo, header=4, index_col='FECHA', parse_dates=True, encoding='utf-8')
xalapaOb.head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-05 18:00:00   121   244         2.3         5.6  20.9  57  867.5
# 2014-11-05 18:10:00   171   258         2.2         4.8  20.3  56  867.2
# 2014-11-05 18:20:00   160   331         1.7         3.7  21.1  56  867.0
# 2014-11-05 18:30:00   150   233         2.0         4.4  20.7  56  866.9
# 2014-11-05 18:40:00   100   164         2.2         4.0  21.0  56  866.6
#
#                      PREC  RADSOL
# FECHA
# 2014-11-05 18:00:00     0     896
# 2014-11-05 18:10:00     0     848
# 2014-11-05 18:20:00     0     861
# 2014-11-05 18:30:00     0     751
# 2014-11-05 18:40:00     0     704

# %%
xalapaOb.columns
# Out:
# Index([u'DIRS', u'DIRR', u'RAPVIENTO2', u'RAPRAFAGA2', u'TEMP', u'HR', u'PB', u'PREC', u'RADSOL'], dtype='object')

# %%
xalapaOb.columns[0]
# Out:
# u'DIRS'

# %%
xalapaOb[[u'DIRS']].head()
# Out:
#                      DIRS
# FECHA
# 2014-11-05 18:00:00   121
# 2014-11-05 18:10:00   171
# 2014-11-05 18:20:00   160
# 2014-11-05 18:30:00   150
# 2014-11-05 18:40:00   100

# %%
xalapaOb[[u'TEMP']].head()
# Out:
#                      TEMP
# FECHA
# 2014-11-05 18:00:00  20.9
# 2014-11-05 18:10:00  20.3
# 2014-11-05 18:20:00  21.1
# 2014-11-05 18:30:00  20.7
# 2014-11-05 18:40:00  21.0

# %%
xalapaOb[['TEMP']]
# Out:
#                      TEMP
# FECHA
# 2014-11-05 18:00:00  20.9
# 2014-11-05 18:10:00  20.3
# 2014-11-05 18:20:00  21.1
# 2014-11-05 18:30:00  20.7
# 2014-11-05 18:40:00  21.0
# 2014-11-05 18:50:00  21.4
# 2014-11-05 19:00:00  22.0
# 2014-11-05 19:10:00  22.1
# 2014-11-05 19:20:00  22.4
# 2014-11-05 19:30:00  21.9
# 2014-11-05 19:40:00  22.2
# 2014-11-05 19:50:00  22.2
# 2014-11-05 20:00:00  22.1
# 2014-11-05 20:10:00  22.2
# 2014-11-05 20:20:00  22.7
# 2014-11-05 20:30:00  23.1
# 2014-11-05 20:40:00  22.3
# 2014-11-05 20:50:00  22.4
# 2014-11-05 21:00:00  22.2
# 2014-11-05 21:10:00  21.5
# 2014-11-05 21:20:00  21.7
# 2014-11-05 21:30:00  21.2
# 2014-11-05 21:40:00  21.2
# 2014-11-05 21:50:00  20.8
# 2014-11-05 22:00:00  20.8
# 2014-11-05 22:10:00  20.5
# 2014-11-05 22:20:00  20.5
# 2014-11-05 22:30:00  20.4
# 2014-11-05 22:40:00  19.9
# 2014-11-05 22:50:00  19.9
# ...                   ...
# 2014-11-06 13:00:00  15.8
# 2014-11-06 13:10:00  15.8
# 2014-11-06 13:20:00  15.9
# 2014-11-06 13:30:00  16.1
# 2014-11-06 13:40:00  17.3
# 2014-11-06 13:50:00  16.8
# 2014-11-06 14:00:00  16.9
# 2014-11-06 14:10:00  17.3
# 2014-11-06 14:20:00  18.2
# 2014-11-06 14:30:00  19.2
# 2014-11-06 14:40:00  19.1
# 2014-11-06 14:50:00  19.1
# 2014-11-06 15:00:00  19.5
# 2014-11-06 15:10:00  20.1
# 2014-11-06 15:20:00  21.0
# 2014-11-06 15:30:00  21.3
# 2014-11-06 15:40:00  21.4
# 2014-11-06 15:50:00  21.6
# 2014-11-06 16:00:00  20.9
# 2014-11-06 16:10:00  21.4
# 2014-11-06 16:20:00  21.4
# 2014-11-06 16:30:00  21.6
# 2014-11-06 16:40:00  21.1
# 2014-11-06 16:50:00  21.8
# 2014-11-06 17:00:00  22.8
# 2014-11-06 17:10:00  22.2
# 2014-11-06 17:20:00  22.2
# 2014-11-06 17:30:00  22.2
# 2014-11-06 17:40:00  22.1
# 2014-11-06 17:50:00   NaN
#
# [144 rows x 1 columns]

# %%
CustomPlot()
xalapaOb.plot()

# %%
xalapaOb.mean()
# Out:
# DIRS          121.223776
# DIRR          199.566434
# RAPVIENTO2      1.076923
# RAPRAFAGA2      2.337063
# TEMP           18.136364
# HR             83.692308
# PB            868.180420
# PREC            0.006993
# RADSOL        170.468531
# dtype: float64

# %%
xalapaOb.mean().plot(kind='bar')

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Temperatura en Xalapa (24 horas)',fontsize = font_size)
plt.xlabel('hora',fontsize = font_size)
plt.ylabel(r'Temperatura [$^\circ C$] ',fontsize = font_size)
xalapaOb.TEMP.plot();

# %%
figsize(11.5, 6)
font_size = 20
plt.title( 'Radiacion solar', fontsize= font_size)
plt.xlabel('horac', fontsize = font_size)
plt.ylabel(r'$MJ / day / m^2$',fontsize = font_size)
xalapaOb.RADSOL.plot();

# %%
xalapaOb.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-11-05 18:00:00, ..., 2014-11-06 17:50:00]
# Length: 144, Freq: None, Timezone: None

# %%
madrugada = xalapaOb['2014-11-05 3:00:00' : '2014-11-06 6:00:00']
madrugada.TEMP.head()
# Out:
# FECHA
# 2014-11-05 18:00:00    20.9
# 2014-11-05 18:10:00    20.3
# 2014-11-05 18:20:00    21.1
# 2014-11-05 18:30:00    20.7
# 2014-11-05 18:40:00    21.0
# Name: TEMP, dtype: float64

# %%
media = xalapaOb.TEMP.mean()
media
# Out:
# 18.136363636363637

# %%
madrugada[madrugada.TEMP <= media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-06 00:30:00   131   226         1.3         2.7  17.8  91  866.9
# 2014-11-06 00:40:00   135   257         1.0         2.1  17.5  92  866.9
# 2014-11-06 00:50:00   127   299         0.9         1.9  17.4  94  867.1
# 2014-11-06 01:00:00   119   299         0.8         2.3  17.2  94  867.3
# 2014-11-06 01:10:00   105   175         1.1         2.2  17.1  95  867.4
#
#                      PREC  RADSOL
# FECHA
# 2014-11-06 00:30:00     0      -1
# 2014-11-06 00:40:00     0      -1
# 2014-11-06 00:50:00     0      -1
# 2014-11-06 01:00:00     0      -1
# 2014-11-06 01:10:00     0      -1

# %%
madrugada[madrugada.TEMP > media].head()
# Out:
#                      DIRS  DIRR  RAPVIENTO2  RAPRAFAGA2  TEMP  HR     PB  \
# FECHA
# 2014-11-05 18:00:00   121   244         2.3         5.6  20.9  57  867.5
# 2014-11-05 18:10:00   171   258         2.2         4.8  20.3  56  867.2
# 2014-11-05 18:20:00   160   331         1.7         3.7  21.1  56  867.0
# 2014-11-05 18:30:00   150   233         2.0         4.4  20.7  56  866.9
# 2014-11-05 18:40:00   100   164         2.2         4.0  21.0  56  866.6
#
#                      PREC  RADSOL
# FECHA
# 2014-11-05 18:00:00     0     896
# 2014-11-05 18:10:00     0     848
# 2014-11-05 18:20:00     0     861
# 2014-11-05 18:30:00     0     751
# 2014-11-05 18:40:00     0     704

# %%
xalapaOb['TEMP'].describe()
# Out:
# count    143.000000
# mean      18.136364
# std        2.538036
# min       15.200000
# 25%       15.800000
# 50%       16.800000
# 75%       20.850000
# max       23.100000
# dtype: float64

# %%
figsize(11.5, 6)
font_size = 20
plt.title('Distribucion de la rapidez del viento', fontsize=font_size)
# plt.ylabel('frecuen',fontsize = font_size)
plt.xlabel('Nudos',fontsize = font_size)
xalapaOb.RAPVIENTO2.hist(bins=6);
