# %%
# %run ../talktools.py
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
#     background: #fff; /* white background for content */
#     width: 1000px;
#     margin: auto;
#     padding-left: 0em;
# }
#
# #notebook li { /* More space between bullet points */
# margin-top:0.8em;
# }
#
# /* draw border around running cells */
# div.cell.border-box-sizing.code_cell.running {
#     border: 1px solid #111;
# }
#
# /* Put a solid color box around each cell and its output, visually linking them*/
# div.cell.code_cell {
#     background-color: rgb(256,256,256);
#     border-radius: 0px;
#     padding: 0.5em;
#     margin-left:1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Alegreya Sans' sans-serif;
#     line-height: 140%;
#     font-size: 125%;
#     font-weight: 400;
#     width:600px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
#
# /* Formatting for header cells */
# .text_cell_render h1 {
#     font-family: 'Nixie One', serif;
#     font-style:regular;
#     font-weight: 400;
#     font-size: 45pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.5em;
#     margin-top: 0.5em;
#     display: block;
# }
# .text_cell_render h2 {
#     font-family: 'Nixie One', serif;
#     font-weight: 400;
#     font-size: 30pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     margin-bottom: 0.1em;
#     margin-top: 0.3em;
#     display: block;
# }
#
# .text_cell_render h3 {
#     font-family: 'Nixie One', serif;
#     margin-top:16px;
# 	font-size: 22pt;
#     font-weight: 600;
#     margin-bottom: 3px;
#     font-style: regular;
#     color: rgb(102,102,0);
# }
#
# .text_cell_render h4 {    /*Use this for captions*/
#     font-family: 'Nixie One', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /*Use this for small titles*/
#     font-family: 'Nixie One', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6 { /*use this for copyright note*/
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# .CodeMirror{
#         font-family: "PT Mono";
#         font-size: 90%;
# }
#
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
file_name = '../files/Sensor_record_20141108_141413_AndroSensor.csv'
sensorData = pd.read_csv(file_name, sep=';', header=1)
sensorData[:10]
# Out:
#    ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                  0.6129                  9.5001                  3.6774
# 1                  0.3065                  9.1936                  4.4436
# 2                 -0.1532                  9.6533                  3.5242
# 3                 -1.5323                  9.6533                  4.9033
# 4                  0.0000                  9.6533                  4.5968
# 5                  1.0726                  8.1210                  5.8226
# 6                  1.9920                  8.7339                  5.5162
# 7                  2.6049                  8.7339                  3.3710
# 8                  2.1452                  7.8146                  6.8952
# 9                  1.9920                  7.6614                  6.4355
#
#    GRAVITY X (m/s²)  GRAVITY Y (m/s²)  GRAVITY Z (m/s²)  \
# 0            0.5906            9.6197            3.4961
# 1            0.2285            9.2844            4.4320
# 2            0.0993            9.2375            4.6470
# 3           -0.5490            9.5454            2.7290
# 4           -1.9391            9.3678            5.2574
# 5            0.1749            8.3958            5.1178
# 6            1.4082            8.5373            5.5299
# 7            2.1924            8.5379            5.0468
# 8            2.2212            8.9065            4.1904
# 9            2.5774            7.9243            6.6819
#
#    LINEAR ACCELERATION X (m/s²)  LINEAR ACCELERATION Y (m/s²)  \
# 0                        0.0223                       -0.1196
# 1                        0.0780                       -0.0908
# 2                       -0.2525                        0.4158
# 3                       -0.9832                        0.1079
# 4                        1.3261                       -0.0209
# 5                        0.8977                       -0.2748
# 6                        0.5838                        0.1966
# 7                        0.4125                        0.1961
# 8                       -0.0760                       -1.0920
# 9                       -0.5854                       -0.2629
#
#    LINEAR ACCELERATION Z (m/s²)  MAGNETIC FIELD X (μT)          ...            \
# 0                        0.1813                  -17.7          ...
# 1                        0.0116                  -19.2          ...
# 2                       -1.1228                  -17.1          ...
# 3                        2.1743                   -1.6          ...
# 4                        0.4120                    2.2          ...
# 5                        0.2452                   -3.6          ...
# 6                       -0.0137                   -6.0          ...
# 7                       -1.6758                  -10.1          ...
# 8                        2.7048                  -12.3          ...
# 9                       -0.2464                  -18.7          ...
#
#    LOCATION Latitude :   LOCATION Longitude :   LOCATION Altitude ( m)  \
# 0             19.519264             -96.914856                     NaN
# 1             19.519264             -96.914856                     NaN
# 2             19.519264             -96.914856                     NaN
# 3             19.519264             -96.914856                     NaN
# 4             19.519264             -96.914856                     NaN
# 5             19.519264             -96.914856                     NaN
# 6             19.519264             -96.914856                     NaN
# 7             19.519264             -96.914856                     NaN
# 8             19.519264             -96.914856                     NaN
# 9             19.519264             -96.914856                     NaN
#
#    LOCATION Speed ( Kmh)  LOCATION Accuracy ( m)  Temperature (F)  Level (%)  \
# 0                    NaN                87.09678             91.4         80
# 1                    NaN                87.09678             91.4         80
# 2                    NaN                87.09678             91.4         80
# 3                    NaN                87.09678             91.4         80
# 4                    NaN                87.09678             91.4         80
# 5                    NaN                87.09678             91.4         80
# 6                    NaN                87.09678             91.4         80
# 7                    NaN                87.09678             91.4         80
# 8                    NaN                87.09678             91.4         80
# 9                    NaN                87.09678             91.4         80
#
#    Voltage (Volt)  Time since start in ms   YYYY-MO-DD HH-MI-SS_SSS
# 0               3                       59  2014-11-08 13:53:58:448
# 1               3                      560  2014-11-08 13:53:58:949
# 2               3                     1060  2014-11-08 13:53:59:449
# 3               3                     1560  2014-11-08 13:53:59:949
# 4               3                     2064  2014-11-08 13:54:00:453
# 5               3                     2564  2014-11-08 13:54:00:953
# 6               3                     3064  2014-11-08 13:54:01:453
# 7               3                     3564  2014-11-08 13:54:01:953
# 8               3                     4064  2014-11-08 13:54:02:453
# 12    2.2984
# 13    2.2984
# 14    1.5323
# ...
# 2397    2.1452
# 2398    2.7581
# 2399    0.7661
# 2400   -1.2258
# 2401   -1.0726
# 2402   -0.7661
# 2403   -0.9194
# 2404   -1.9920
# 2405    1.2258
# 2406    0.1532
# 2407    0.7661
# 2408    2.6049
# 2409    2.7581
# 2410    2.2984
# 2411    2.6049
# Name: ACCELEROMETER X (m/s²), Length: 2412, dtype: float64

# %%
geodatos=sensorData.iloc[:,17:19]
geodatos[:10]
# Out:
#    LOCATION Latitude :   LOCATION Longitude :
# 0             19.519264             -96.914856
# 1             19.519264             -96.914856
# 2             19.519264             -96.914856
# 3             19.519264             -96.914856
# 4             19.519264             -96.914856
# 5             19.519264             -96.914856
# 6             19.519264             -96.914856
# 7             19.519264             -96.914856
# 8             19.519264             -96.914856
# 9             19.519264             -96.914856

# %%
# %matplotlib inline

# %%
sensorData.plot(legend=False)

# %%
geodatos.plot()

# %%
geodatos.keys()
# Out:
# Index([u'LOCATION Latitude : ', u'LOCATION Longitude : '], dtype='object')

# %%
geodatos.keys()[0]
# Out:
# 'LOCATION Latitude : '

# %%
geodatos.plot(x=geodatos.keys()[0], y=geodatos.keys()[1], kind='scatter')

# %%
from mpl_toolkits.basemap import Basemap
from datetime import datetime

# %%
lats = geodatos.values[:,0]
lons = geodatos.values[:,1]

# %%
geodatos.values[:,0]
# Out:
# array([ 19.519264,  19.519264,  19.519264, ...,  19.520164,  19.520164,
#         19.520164])

# %%
m = Basemap(projection='hammer',lon_0=-90)

x, y = m(lons,lats)

m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff')
m.scatter(x,y,24,marker='o',color='k')
plt.text(x[-1],y[-1],'LANIA',color='b');

# %%
map = Basemap(projection='mill',lon_0=-90)
# plot coastlines, draw label meridians and parallels.
map.drawcoastlines()
map.drawparallels(np.arange(-90,90,30),labels=[1,0,0,0])
map.drawmeridians(np.arange(map.lonmin,map.lonmax+30,60),labels=[0,0,0,1])
# fill continents 'coral' (with zorder=0), color wet areas 'aqua'
map.drawmapboundary(fill_color='#99ffff')
map.fillcontinents(color='coral',lake_color='#99ffff')
x, y = map(lons,lats)
map.scatter(x,y,24,marker='o', color='b')
plt.text(x[-1],y[-1],'LANIA',color='b');

# %%
timestamp = sensorData.iloc[:,32:33]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0c56f9daf3de> in <module>()
# ----> 1 timestamp = sensorData.iloc[:,32:33]
#
# NameError: name 'sensorData' is not defined

# %%
from datetime import datetime
import calendar

# %%
UnTimestamp = str(timestamp.values[-1]).split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8b5934106d73> in <module>()
# ----> 1 UnTimestamp = str(timestamp.values[-1]).split()
#
# NameError: name 'timestamp' is not defined

# %%
fechaSinFormatear = UnTimestamp [0]
fechaSplit= fechaSinFormatear.split("-")

anio = int(fechaSplit[0][2: ]) #comenzar en la segunda posicion del string, para obtener el año
mes = int(fechaSplit[1])
dia = int(fechaSplit[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ea7891144c84> in <module>()
# ----> 1 fechaSinFormatear = UnTimestamp [0]
#       2 fechaSplit= fechaSinFormatear.split("-")
#       3
#       4 anio = int(fechaSplit[0][2: ]) #comenzar en la segunda posicion del string, para obtener el año
#       5 mes = int(fechaSplit[1])
#
# NameError: name 'UnTimestamp' is not defined
